# %% [markdown]
# <a href="https://colab.research.google.com/github/codebiney/torch-tutorial/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([10,20,30,40])
plt.show()

# %%
plt.title("yb,cs")
plt.xlabel("year")
plt.ylabel("height")
plt.plot([11,12,13,14],[138,140,145,150],'r',label = 'yeahbin')
plt.plot([11,12,13,14],[138,145,150,168],'b',label = 'ocs')

plt.show()

# %%
arr1 = []
arr2 = []
arr3 = []
arr4 = []

import csv
f = open('/content/sample_data/gwang ju.csv',encoding='cp949')
data = csv.reader(f,delimiter=',')
header = next(data)
for row in data:
  y,m,d = row[0].split('-')
  m = int(m)
  d = int(d)
  if m == 8 and d == 17:
    arr1.append(row[0])
    arr2.append(row[2])
    arr3.append(row[3])
    arr4.append(row[4])





plt.title('yw.birth')
plt.xlabel('year')
plt.ylabel('temp')
plt.plot(arr1,arr2,'r')
plt.plot(arr1,arr3,'b')
plt.plot(arr1,arr4,'black')

plt.show()
